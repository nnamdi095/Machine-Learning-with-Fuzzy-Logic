# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np
from skfuzzy import control as ctrl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt;

# %%
#LOAD DATASET
data_all = pd.read_pickle('choy_data.pkl')
data_all.head()
# Out:
#    heat index  humidity   moisture    soil_sens  temperature       wind  \
# 0   27.368090      72.0  38.599998  2077.600098    26.000000  12.553803
# 1   25.590635      73.0  37.900002  2083.399902    26.000000  13.458583
# 2   25.590635      72.0  37.900002  2085.699951    24.877772   3.153467
# 3   27.368090      72.0  38.299999  2085.300049    26.000000  13.910973
# 4   27.368090      72.0  38.099998  2077.600098    26.000000  12.044867
#
#       light        date      time
# 0  5.934079  2020-12-26  12:09:31
# 1  8.163333  2020-12-26  12:10:23
# 2  8.426666  2020-12-26  12:11:16
# 3  7.373333  2020-12-26  12:11:52
# 4  7.241666  2020-12-26  12:12:47

# %%
data = data_all.copy()
data = data[['humidity','temperature','heat index']]
data.head()
# Out:
#    humidity  temperature  heat index
# 0      72.0    26.000000   27.368090
# 1      73.0    26.000000   25.590635
# 2      72.0    24.877772   25.590635
# 3      72.0    26.000000   27.368090
# 4      72.0    26.000000   27.368090

# %%
data.describe()
# Out:
#            humidity   temperature    heat index
# count  23566.000000  23566.000000  23566.000000
# mean      75.815305     24.877772     25.525115
# std        3.383278      0.784143      1.080773
# min       63.000000     23.000000     23.339767
# 25%       74.000000     24.000000     24.544199
# 50%       76.000000     25.000000     25.513636
# 75%       78.000000     25.000000     25.591967
# max       85.000000     28.000000     30.666147

# %%
#k = data[data.humidity > 79]
#pd.options.display.min_rows = 3000

# %%
data.quantile(0.25)
# Out:
# humidity       74.000000
# temperature    24.000000
# heat index     24.544199
# Name: 0.25, dtype: float64

# %%
def identify_outliers(data):
    q1, q3 = data.quantile(0.25), data.quantile(0.75)
    iqr = q3 - q1
    cut_off = iqr * 1.5
    data_clean = data[~((data < (q1 - cut_off)) |(data > (q3 + cut_off))).any(axis=1)]
    return data_clean
data = identify_outliers(data)

# %% [markdown]
# ## Univariate Exploration

# %%
#DESCRIPTIVE STATISTICS
data.describe()
# Out:
#            humidity   temperature    heat index
# count  19717.000000  19717.000000  19717.000000
# mean      76.485849     24.622391     25.109856
# std        2.752027      0.543842      0.517683
# min       68.000000     23.000000     23.339767
# 25%       75.000000     24.000000     24.518085
# 50%       76.000000     25.000000     25.461412
# 75%       79.000000     25.000000     25.539745
# max       84.000000     26.000000     25.696409

# %% [markdown]
# ## Multivariate Exploration

# %%
# CHECKING FOR PREDICTIVE CORRELATION
corr = data.corr()
corr.style.background_gradient(cmap='BuGn', axis=None)
# Out:
# <style  type="text/css" >
# #T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col0,#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col1,#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col1,#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col0{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col2,#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col0{
#             background-color:  #eaf7fa;
#             color:  #000000;
#         }#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col2,#T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col1{
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }</style><table id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >humidity</th>        <th class="col_heading level0 col1" >temperature</th>        <th class="col_heading level0 col2" >heat index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9level0_row0" class="row_heading level0 row0" >humidity</th>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col1" class="data row0 col1" >-0.470903</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row0_col2" class="data row0 col2" >-0.334338</td>
#             </tr>
#             <tr>
#                         <th id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9level0_row1" class="row_heading level0 row1" >temperature</th>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col0" class="data row1 col0" >-0.470903</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row1_col2" class="data row1 col2" >0.947771</td>
#             </tr>
#             <tr>
#                         <th id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9level0_row2" class="row_heading level0 row2" >heat index</th>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col0" class="data row2 col0" >-0.334338</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col1" class="data row2 col1" >0.947771</td>
#                         <td id="T_4ee3e25e_c44d_11eb_8551_70c94e3869d9row2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
corr2 = data.corr()
ax = sns.heatmap(
    corr2, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True
)

#ax.set_xticklabels(
#    ax.get_xticklabels(),
#    rotation=45,
#    horizontalalignment='right');

# %% [markdown]
# ## Data Sampling

# %%
data = data.rename(columns={'heat index': 'heat'})
data.heat=data.heat.round(1)
data.to_pickle('data_hth.pkl')

# %%
#DIVIDE DATASET
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, test_size=0.3, random_state=1)

# %% [markdown]
# ## Model Development

# %%
def get_range(data):
    data_range = pd.DataFrame(columns = data.columns, index = ['max', 'min'])
    data_range.loc['max'] = [data[col].max() for col in data.columns]
    data_range.loc['min'] = [data[col].min() for col in data.columns]
    return data_range

range_df = get_range(data)
range_df
# Out:
#     humidity temperature  heat
# max       84          26  25.7
# min       68          23  23.3

# %%
#SPECIFY UNIVERSE OF DISCOURSE
universe = []
for col in range_df.columns:
        universe_col = np.arange(np.floor(range_df[col].min()), np.ceil(range_df[col].max()+1), 0.1)
        universe.append(universe_col)

# %%
# MEDIAN FUNCTION
def med(l, u):
    return np.median(np.arange(l, u, 0.1))

# %%
#Visualie membership fn

humidity = ctrl.Antecedent(universe[0], 'humidity')
temperature = ctrl.Antecedent(universe[1], 'temperature')
heat = ctrl.Consequent(universe[2], 'heat')

#BUILD MEMBERSHIP FUNCTIONS
humidity['low'] =     fuzz.trimf(universe[0], [68, 68, med(68,83)])
humidity['mid'] =     fuzz.trimf(universe[0], [68, med(68,83), 84])
humidity['high'] =     fuzz.trimf(universe[0], [med(68,83), 84, 84])

temperature['low'] =  fuzz.trimf(universe[1],  [23, 23, med(23,26)])
temperature['mid'] =  fuzz.trimf(universe[1],  [23, med(23,26), 26])
temperature['high'] =  fuzz.trimf(universe[1], [med(23,26), 26, 26])
 
heat['low'] =         fuzz.trimf(universe[2],  [23.3, 23.3, med(23.3,25.8)])
heat['mid'] =         fuzz.trimf(universe[2],  [23.3, med(23.3,25.8), 25.7])
heat['high'] =         fuzz.trimf(universe[2], [med(23.3,25.8), 25.7, 25.7])

for i in range(1):
    humidity.view()
    temperature.view() 
    heat.view()
# Out:
# C:\Python\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Python\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Python\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
hum_lo  = fuzz.trimf(universe[0], [68, 68, med(68,83)])
hum_mid = fuzz.trimf(universe[0], [68, med(68,83), 84])
hum_hi  =  fuzz.trimf(universe[0], [med(68,83), 84, 84])

temp_lo  = fuzz.trimf(universe[1], [23, 23, med(23,26.1)])
temp_mid = fuzz.trimf(universe[1], [23, med(23,26.1), 26])
temp_hi  = fuzz.trimf(universe[1], [med(23,26.1), 26, 26])


heat_lo  = fuzz.trimf(universe[2], [23.3, 23.3, med(23.3,25.8)])
heat_mid = fuzz.trimf(universe[2], [23.3, med(23.3,25.8), 25.7])
heat_hi  = fuzz.trimf(universe[2], [med(23.3,25.8), 25.7, 25.7])

# %%
range_df
# Out:
#     humidity temperature  heat
# max       84          26  25.7
# min       68          23  23.3

# %%
#plt.plot(hum_lo)
#plt.plot(hum_mid)
#plt.plot(hum_hi)

# %%
#FUZZIFY  TRAIN SET HUMIDITY
def fuzzify_hum(hum_val):
    hum_df = pd.DataFrame(hum_val)
    hum_df['low'] = fuzz.interp_membership(universe[0], hum_lo, hum_val)
    hum_df['mid'] = fuzz.interp_membership(universe[0], hum_mid, hum_val)
    hum_df['high'] = fuzz.interp_membership(universe[0], hum_hi, hum_val)

    hum_df['membership'] = hum_df.loc[:, ['low', 'mid', 'high']].idxmax(axis = 1)
    hum_df['degree'] = hum_df.loc[:, ['low', 'mid', 'high']].max(axis = 1)
    return hum_df

hum_val = train_data.iloc[:,0]
hum_df = fuzzify_hum(hum_val)
hum_df
# Out:
#        humidity       low       mid      high membership    degree
# 6101       74.0  0.194631  0.805369  0.000000        mid  0.805369
# 9966       76.0  0.000000  0.935673  0.064327        mid  0.935673
# 14034      79.0  0.000000  0.584795  0.415205        mid  0.584795
# 21924      77.0  0.000000  0.818713  0.181287        mid  0.818713
# 14190      76.0  0.000000  0.935673  0.064327        mid  0.935673
# ...         ...       ...       ...       ...        ...       ...
# 13762      83.0  0.000000  0.116959  0.883041       high  0.883041
# 20724      77.0  0.000000  0.818713  0.181287        mid  0.818713
# 6495       74.0  0.194631  0.805369  0.000000        mid  0.805369
# 15192      80.0  0.000000  0.467836  0.532164       high  0.532164
# 386        75.0  0.060403  0.939597  0.000000        mid  0.939597
#
# [13801 rows x 6 columns]

# %%
hum_df.groupby(by='membership')['membership'].count()
# Out:
# membership
# high     2579
# low       417
# mid     10805
# Name: membership, dtype: int64

# %%
#FUZZIFY TRAIN SET TEMPERATURE
 
def fuzzify_temp(temp_val):
    temp_df = pd.DataFrame(temp_val)
    temp_df['low'] = fuzz.interp_membership(universe[1], temp_lo, temp_val)
    temp_df['mid'] = fuzz.interp_membership(universe[1], temp_mid, temp_val)
    temp_df['high'] = fuzz.interp_membership(universe[1], temp_hi, temp_val)

    temp_df['membership'] = temp_df.loc[:, ['low', 'mid', 'high']].idxmax(axis = 1)
    temp_df['degree'] = temp_df.loc[:, ['low', 'mid', 'high']].max(axis = 1)
    return temp_df
temp_val  = train_data.iloc[:,1]       
temp_df = fuzzify_temp(temp_val)
temp_df
# Out:
#        temperature       low       mid      high membership    degree
# 6101          25.0  0.000000  0.689655  0.310345        mid  0.689655
# 9966          25.0  0.000000  0.689655  0.310345        mid  0.689655
# 14034         25.0  0.000000  0.689655  0.310345        mid  0.689655
# 21924         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 14190         25.0  0.000000  0.689655  0.310345        mid  0.689655
# ...            ...       ...       ...       ...        ...       ...
# 13762         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 20724         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 6495          25.0  0.000000  0.689655  0.310345        mid  0.689655
# 15192         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 386           25.0  0.000000  0.689655  0.310345        mid  0.689655
#
# [13801 rows x 6 columns]

# %%
temp_df.groupby(by='membership')['membership'].count()
# Out:
# membership
# high      433
# low        10
# mid     13358
# Name: membership, dtype: int64

# %%
#FUZZIFY TRAIN SET LIGHT INTENSITY
def fuzzify_heat(heat_val):
    heat_df = pd.DataFrame(heat_val)
    heat_df['low'] = fuzz.interp_membership(universe[2], heat_lo, heat_val)
    heat_df['mid'] = fuzz.interp_membership(universe[2], heat_mid,heat_val)
    heat_df['high'] = fuzz.interp_membership(universe[2],heat_hi, heat_val)

    heat_df['membership'] = heat_df.loc[:, ['low', 'mid', 'high']].idxmax(axis = 1)
    heat_df['degree'] = heat_df.loc[:, ['low', 'mid', 'high']].max(axis = 1)
    return heat_df
heat_val = train_data.iloc[:,2]
heat_df = fuzzify_heat(heat_val)
heat_df
# Out:
#        heat           low       mid          high membership    degree
# 6101   25.5  0.000000e+00  0.166667  8.333333e-01       high  0.833333
# 9966   25.5  0.000000e+00  0.166667  8.333333e-01       high  0.833333
# 14034  25.6  0.000000e+00  0.083333  9.166667e-01       high  0.916667
# 21924  24.5  1.776357e-14  1.000000  2.960595e-15        mid  1.000000
# 14190  25.5  0.000000e+00  0.166667  8.333333e-01       high  0.833333
# ...     ...           ...       ...           ...        ...       ...
# 13762  24.6  0.000000e+00  0.916667  8.333333e-02        mid  0.916667
# 20724  24.5  1.776357e-14  1.000000  2.960595e-15        mid  1.000000
# 6495   25.5  0.000000e+00  0.166667  8.333333e-01       high  0.833333
# 15192  24.5  1.776357e-14  1.000000  2.960595e-15        mid  1.000000
# 386    25.5  0.000000e+00  0.166667  8.333333e-01       high  0.833333
#
# [13801 rows x 6 columns]

# %%
heat_df.groupby(by='membership')['membership'].count()
# Out:
# membership
# high    8194
# low       10
# mid     5597
# Name: membership, dtype: int64

# %%
# Merge the membership columns from predictors and target to get an initial rule set
#----convert numerical values to linguistic values

def merge_rule(df, hum_df, temp_df, heat_df):
    rule_df = df.copy()
    rule_df['humidity'] = hum_df['membership']
    rule_df['temperature'] = temp_df['membership']
    rule_df['heat'] = heat_df['membership']
    rule_df['degree'] = hum_df['degree']*temp_df['degree']*heat_df['degree']
    return rule_df
 
rule_df = merge_rule(train_data, hum_df, temp_df, heat_df)
rule_df
# Out:
#       humidity temperature  heat    degree
# 6101       mid         mid  high  0.462856
# 9966       mid         mid  high  0.537743
# 14034      mid         mid  high  0.369698
# 21924      mid         mid   mid  0.528202
# 14190      mid         mid  high  0.537743
# ...        ...         ...   ...       ...
# 13762     high         mid   mid  0.522229
# 20724      mid         mid   mid  0.528202
# 6495       mid         mid  high  0.462856
# 15192     high         mid   mid  0.343331
# 386        mid         mid  high  0.539998
#
# [13801 rows x 4 columns]

# %%
train_data
# Out:
#        humidity  temperature  heat
# 6101       74.0         25.0  25.5
# 9966       76.0         25.0  25.5
# 14034      79.0         25.0  25.6
# 21924      77.0         24.0  24.5
# 14190      76.0         25.0  25.5
# ...         ...          ...   ...
# 13762      83.0         24.0  24.6
# 20724      77.0         24.0  24.5
# 6495       74.0         25.0  25.5
# 15192      80.0         24.0  24.5
# 386        75.0         25.0  25.5
#
# [13801 rows x 3 columns]

# %%
#Resolve conflicts to get a final rule set

rule_fuzzy = rule_df.groupby(['humidity', 'temperature']).max()
rule_fuzzy = rule_fuzzy.reset_index()
rule_fuzzy_deg = rule_fuzzy.pop('degree')
rule_fuzzy
# Out:
#   humidity temperature  heat
# 0     high         low   low
# 1     high         mid   mid
# 2      low         mid   mid
# 3      mid        high  high
# 4      mid         low   low
# 5      mid         mid   mid

# %%
frule_pvt = rule_fuzzy.pivot(index='temperature', columns='humidity', values='heat')
frule_pvt
# Out:
# humidity    high  low   mid
# temperature
# high         NaN  NaN  high
# low          low  NaN   low
# mid          mid  mid   mid

# %% [markdown]
# ## Predictive Modelling

# %%
#SET UP TEST DATA

test_data.reset_index(drop=True, inplace=True)
y_test = test_data.loc[:,'heat']
test_data
# Out:
#       humidity  temperature  heat
# 0         80.0         24.0  24.5
# 1         74.0         25.0  25.5
# 2         76.0         25.0  25.5
# 3         77.0         24.0  24.5
# 4         80.0         24.0  24.5
# ...        ...          ...   ...
# 5911      76.0         24.0  24.4
# 5912      76.0         25.0  25.5
# 5913      78.0         24.0  24.5
# 5914      75.0         25.0  25.5
# 5915      72.0         25.0  25.4
#
# [5916 rows x 3 columns]

# %%
#FUZZIFY TEST SET HUMIDITY VALUES

test_hum_val = test_data.iloc[:,0]
test_hum_df = fuzzify_hum(test_hum_val)
test_hum_df
# Out:
#       humidity       low       mid      high membership    degree
# 0         80.0  0.000000  0.467836  0.532164       high  0.532164
# 1         74.0  0.194631  0.805369  0.000000        mid  0.805369
# 2         76.0  0.000000  0.935673  0.064327        mid  0.935673
# 3         77.0  0.000000  0.818713  0.181287        mid  0.818713
# 4         80.0  0.000000  0.467836  0.532164       high  0.532164
# ...        ...       ...       ...       ...        ...       ...
# 5911      76.0  0.000000  0.935673  0.064327        mid  0.935673
# 5912      76.0  0.000000  0.935673  0.064327        mid  0.935673
# 5913      78.0  0.000000  0.701754  0.298246        mid  0.701754
# 5914      75.0  0.060403  0.939597  0.000000        mid  0.939597
# 5915      72.0  0.463087  0.536913  0.000000        mid  0.536913
#
# [5916 rows x 6 columns]

# %%
#FUZZIFY TEST TEMPERATURE VALUES

test_temp_val = test_data.iloc[:,1]
test_temp_df = fuzzify_temp(test_temp_val)
test_temp_df
# Out:
#       temperature       low       mid      high membership    degree
# 0            24.0  0.354839  0.645161  0.000000        mid  0.645161
# 1            25.0  0.000000  0.689655  0.310345        mid  0.689655
# 2            25.0  0.000000  0.689655  0.310345        mid  0.689655
# 3            24.0  0.354839  0.645161  0.000000        mid  0.645161
# 4            24.0  0.354839  0.645161  0.000000        mid  0.645161
# ...           ...       ...       ...       ...        ...       ...
# 5911         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 5912         25.0  0.000000  0.689655  0.310345        mid  0.689655
# 5913         24.0  0.354839  0.645161  0.000000        mid  0.645161
# 5914         25.0  0.000000  0.689655  0.310345        mid  0.689655
# 5915         25.0  0.000000  0.689655  0.310345        mid  0.689655
#
# [5916 rows x 6 columns]

# %%
#DEFINE THE CENTER OF THE FUZZY REGIONS FOR TEMPERATURE

def fuzzr_center(a):
    if a == 'low':
        return range_df.loc['min','heat']-0.5
    if a == 'mid':
        return med(range_df.loc['min','heat'], range_df.loc['max','heat'])+0.9
    if a == 'high':
        return range_df.loc['max','heat']+0.2
fuzzr_center('mid')
# Out:
# 25.350000000000016

# %%
#PASS TEST DATA THROUGH EACH RULE AND AGGREGATE OUTPUT

ynum = np.zeros([y_test.shape[0], rule_fuzzy.shape[0]])
ydenom = np.zeros([y_test.shape[0], rule_fuzzy.shape[0]])
for i, fser in test_data.iterrows():
    for j, rser in rule_fuzzy.iterrows():
        col = rser.values
        rule_acx_num =test_hum_df.loc[i,col[0]] * test_temp_df.loc[i,col[1]]*fuzzr_center(col[2])
        rule_acx_denom =test_hum_df.loc[i,col[0]]*test_temp_df.loc[i,col[1]]
        ynum[i,j] = rule_acx_num
        ydenom[i,j] = rule_acx_denom

# %%
#COMPUTE THE PREDICTED TEMPERATURE
sum_ynum = np.sum(ynum, axis=1)
sum_ydenom = np.sum(ydenom, axis=1)
y_pred = sum_ynum/sum_ydenom
y_pred
# Out:
# array([24.44516129, 25.49630542, 25.51296296, ..., 24.44516129,
#        25.5134434 , 25.45702703])

# %%
y_test
# Out:
# 0       24.5
# 1       25.5
# 2       25.5
# 3       24.5
# 4       24.5
#         ...
# 5911    24.4
# 5912    25.5
# 5913    24.5
# 5914    25.5
# 5915    25.4
# Name: heat, Length: 5916, dtype: float64

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error
model_r2 = r2_score(y_test, y_pred)
model_mse = mean_squared_error(y_test, y_pred)
print('$R^2$', model_r2)
print('RMSE: ', np.sqrt(model_mse))
# Out:
# $R^2$ 0.9652074323599097
# RMSE:  0.09747556285727847

# %%
plt.figure(figsize=(8,4))
plt.plot(y_pred, linewidth=0.5, color='orange', label='prediction')
plt.plot(y_test, linewidth=0.5, linestyle='-.', color='black', label='true value')
plt.ylabel('heat index($^0C$)')
plt.legend(loc='lower left')
#plt.delaxes('top')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# %% [markdown]
# ## Performance Comparison

# %%
# SET UP TRAIN DATA

X_train = train_data.copy()
y_train = X_train.pop('heat')
X_train.to_numpy()
y_train.to_numpy()
# Out:
# array([25.5, 25.5, 25.6, ..., 25.5, 24.5, 25.5])

# %%
#SET UP TEST DATA

X_test = test_data.copy()
y_test = X_test.pop('heat')
X_test.to_numpy()
y_test.to_numpy()
# Out:
# array([24.5, 25.5, 25.5, ..., 24.5, 25.5, 25.4])

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor

# %%
model_names = ['Dummy', 'Linear', 'Lasso', 'Random Forest']

models = [
    DummyRegressor(strategy='median'),
    LinearRegression(fit_intercept=False),
    Lasso(fit_intercept=False),
    RandomForestRegressor(n_estimators=50, n_jobs=-1)
    ]

# %%
for name, model in zip(model_names, models):
    model.fit(X_train, y_train)
    y_predd=model.predict(X_test)
    print(name, r2_score(y_test, y_predd))
# Out:
# Dummy -0.5877716486098139
# Linear 0.917549749906729
# Lasso -0.33868707436049283
# Random Forest 1.0
